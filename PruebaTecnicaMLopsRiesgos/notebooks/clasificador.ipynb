# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
import re 
import nltk
import spacy
import warnings
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import Counter
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
warnings.filterwarnings('ignore')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sebastian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/sebastian/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
path = os.getcwd()
full_df = pd.read_csv(f'{path}/df_entrenamiento_cluster.csv', encoding='latin1')

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953439 entries, 0 to 953438
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           953439 non-null  int64
#  1   Id                   953439 non-null  int64
#  2   OwnerUserId          941191 non-null  float64
#  3   CreationDate         953439 non-null  object
#  4   Score                953439 non-null  int64
#  5   text                 953439 non-null  object
#  6   label                953439 non-null  int64
#  7   descripcion_cluster  953439 non-null  object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 58.2+ MB

# %%
full_df.head()
# Out:
#    Unnamed: 0   Id  OwnerUserId          CreationDate  Score  \
# 0           0   80         26.0  2008-08-01T13:57:07Z     26
# 1           1   90         58.0  2008-08-01T14:41:24Z    144
# 2           2  120         83.0  2008-08-01T15:50:08Z     21
# 3           3  180    2089740.0  2008-08-01T18:42:19Z     53
# 4           4  260         91.0  2008-08-01T23:22:08Z     49
#
#                                                 text  label  \
# 0  SQLStatement.execute() - multiple queries in o...     12
# 1  Good branching and merging tutorials for Torto...      6
# 2                                  ASP.NET Site Maps      6
# 3                 Function for creating color wheels      6
# 4  Adding scripting functionality to .NET applica...      6
#
#                                  descripcion_cluster
# 0  Problemas de manejar multiples entidades: cone...
# 1  Temas generales de desarrollo: branching, scri...
# 2  Temas generales de desarrollo: branching, scri...
# 3  Temas generales de desarrollo: branching, scri...
# 4  Temas generales de desarrollo: branching, scri...

# %%
full_df = full_df.drop('Unnamed: 0', axis=1)
full_df['text'] = full_df['text'].astype(str)
df = full_df.reset_index(drop=True)

# %%
def remove_punc(text):
    return text.translate(str.maketrans('','',punc_to_remove))
def remove_stopwords(text, stpwords):
    return ' '.join([word for word in str(text).split() if word not in stpwords])
def remove_freqwords(text):
    return ' '.join([word for word in str(text).split() if word not in freqwords])
def lemmatize_words(text):
    return ' '.join([lemmatizer.lemmatize(word) for word in text.split()])
def stem_words(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])
def remove_numbers(text):
    return re.sub(r"\d+", "", text)
def remove_account(text):
    return re.sub(r"@\w+", "", text)

# %%
df['text_lower'] = df['text'].str.lower()
df.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z     26
# 1   90         58.0  2008-08-01T14:41:24Z    144
# 2  120         83.0  2008-08-01T15:50:08Z     21
# 3  180    2089740.0  2008-08-01T18:42:19Z     53
# 4  260         91.0  2008-08-01T23:22:08Z     49
#
#                                                 text  label  \
# 0  SQLStatement.execute() - multiple queries in o...     12
# 1  Good branching and merging tutorials for Torto...      6
# 2                                  ASP.NET Site Maps      6
# 3                 Function for creating color wheels      6
# 4  Adding scripting functionality to .NET applica...      6
#
#                                  descripcion_cluster  \
# 0  Problemas de manejar multiples entidades: cone...
# 1  Temas generales de desarrollo: branching, scri...
# 2  Temas generales de desarrollo: branching, scri...
# 3  Temas generales de desarrollo: branching, scri...
# 4  Temas generales de desarrollo: branching, scri...
#
#                                           text_lower
# 0  sqlstatement.execute() - multiple queries in o...
# 1  good branching and merging tutorials for torto...
# 2                                  asp.net site maps
# 3                 function for creating color wheels
# 4  adding scripting functionality to .net applica...

# %%
punc_to_remove= string.punctuation.replace('.','')
df['punc_remove']=df['text_lower'].apply(remove_punc)
df.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z     26
# 1   90         58.0  2008-08-01T14:41:24Z    144
# 2  120         83.0  2008-08-01T15:50:08Z     21
# 3  180    2089740.0  2008-08-01T18:42:19Z     53
# 4  260         91.0  2008-08-01T23:22:08Z     49
#
#                                                 text  label  \
# 0  SQLStatement.execute() - multiple queries in o...     12
# 1  Good branching and merging tutorials for Torto...      6
# 2                                  ASP.NET Site Maps      6
# 3                 Function for creating color wheels      6
# 4  Adding scripting functionality to .NET applica...      6
#
#                                  descripcion_cluster  \
# 0  Problemas de manejar multiples entidades: cone...
# 1  Temas generales de desarrollo: branching, scri...
# 2  Temas generales de desarrollo: branching, scri...
# 3  Temas generales de desarrollo: branching, scri...
# 4  Temas generales de desarrollo: branching, scri...
#
#                                           text_lower  \
# 0  sqlstatement.execute() - multiple queries in o...
# 1  good branching and merging tutorials for torto...
# 2                                  asp.net site maps
# 3                 function for creating color wheels
# 4  adding scripting functionality to .net applica...
#
#                                          punc_remove
# 0  sqlstatement.execute  multiple queries in one ...
# 1  good branching and merging tutorials for torto...
# 2                                  asp.net site maps
# 3                 function for creating color wheels
# 4  adding scripting functionality to .net applica...

# %%
stpwords= set(stopwords.words('english'))
df['stopwords_remove']= df['punc_remove'].apply(lambda text: remove_stopwords(text,stpwords))
df.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z     26
# 1   90         58.0  2008-08-01T14:41:24Z    144
# 2  120         83.0  2008-08-01T15:50:08Z     21
# 3  180    2089740.0  2008-08-01T18:42:19Z     53
# 4  260         91.0  2008-08-01T23:22:08Z     49
#
#                                                 text  label  \
# 0  SQLStatement.execute() - multiple queries in o...     12
# 1  Good branching and merging tutorials for Torto...      6
# 2                                  ASP.NET Site Maps      6
# 3                 Function for creating color wheels      6
# 4  Adding scripting functionality to .NET applica...      6
#
#                                  descripcion_cluster  \
# 0  Problemas de manejar multiples entidades: cone...
# 1  Temas generales de desarrollo: branching, scri...
# 2  Temas generales de desarrollo: branching, scri...
# 3  Temas generales de desarrollo: branching, scri...
# 4  Temas generales de desarrollo: branching, scri...
#
#                                           text_lower  \
# 0  sqlstatement.execute() - multiple queries in o...
# 1  good branching and merging tutorials for torto...
# 2                                  asp.net site maps
# 3                 function for creating color wheels
# 4  adding scripting functionality to .net applica...
#
#                                          punc_remove  \
# 0  sqlstatement.execute  multiple queries in one ...
# 1  good branching and merging tutorials for torto...
# 2                                  asp.net site maps
# 3                 function for creating color wheels
# 4  adding scripting functionality to .net applica...
#
#                                     stopwords_remove
# 0  sqlstatement.execute multiple queries one stat...
# 1       good branching merging tutorials tortoisesvn
# 2                                  asp.net site maps
# 3                     function creating color wheels
# 4   adding scripting functionality .net applications

# %%
ct= Counter()

for t in df['stopwords_remove'].values:
   for w in t.split():
        ct[w] +=1

freqwords = set([w for (w, wc) in ct.most_common(10)])
df['freq_word_remove']= df['stopwords_remove'].apply(remove_freqwords)
df.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z     26
# 1   90         58.0  2008-08-01T14:41:24Z    144
# 2  120         83.0  2008-08-01T15:50:08Z     21
# 3  180    2089740.0  2008-08-01T18:42:19Z     53
# 4  260         91.0  2008-08-01T23:22:08Z     49
#
#                                                 text  label  \
# 0  SQLStatement.execute() - multiple queries in o...     12
# 1  Good branching and merging tutorials for Torto...      6
# 2                                  ASP.NET Site Maps      6
# 3                 Function for creating color wheels      6
# 4  Adding scripting functionality to .NET applica...      6
#
#                                  descripcion_cluster  \
# 0  Problemas de manejar multiples entidades: cone...
# 1  Temas generales de desarrollo: branching, scri...
# 2  Temas generales de desarrollo: branching, scri...
# 3  Temas generales de desarrollo: branching, scri...
# 4  Temas generales de desarrollo: branching, scri...
#
#                                           text_lower  \
# 0  sqlstatement.execute() - multiple queries in o...
# 1  good branching and merging tutorials for torto...
# 2                                  asp.net site maps
# 3                 function for creating color wheels
# 4  adding scripting functionality to .net applica...
#
#                                          punc_remove  \
# 0  sqlstatement.execute  multiple queries in one ...
# 1  good branching and merging tutorials for torto...
# 2                                  asp.net site maps
# 3                 function for creating color wheels
# 4  adding scripting functionality to .net applica...
#
#                                     stopwords_remove  \
# 0  sqlstatement.execute multiple queries one stat...
# 1       good branching merging tutorials tortoisesvn
# 2                                  asp.net site maps
# 3                     function creating color wheels
# 4   adding scripting functionality .net applications
#
#                                     freq_word_remove
# 0  sqlstatement.execute multiple queries one stat...
# 1       good branching merging tutorials tortoisesvn
# 2                                  asp.net site maps
# 3                     function creating color wheels
# 4   adding scripting functionality .net applications

# %%
lemmatizer= WordNetLemmatizer()
df['text_lemmatize']= df['freq_word_remove'].apply(lemmatize_words)
df.head(-1)
# Out:
#               Id  OwnerUserId          CreationDate  Score  \
# 0             80         26.0  2008-08-01T13:57:07Z     26
# 1             90         58.0  2008-08-01T14:41:24Z    144
# 2            120         83.0  2008-08-01T15:50:08Z     21
# 3            180    2089740.0  2008-08-01T18:42:19Z     53
# 4            260         91.0  2008-08-01T23:22:08Z     49
# ...          ...          ...                   ...    ...
# 953433  33112560    1219968.0  2015-10-13T21:02:04Z      2
# 953434  33112570    5427938.0  2015-10-13T21:02:41Z      2
# 953435  33112630    5442641.0  2015-10-13T21:06:46Z     -2
# 953436  33112660    1754127.0  2015-10-13T21:08:36Z      0
# 953437  33112730    3841384.0  2015-10-13T21:13:06Z      1
#
#                                                      text  label  \
# 0       SQLStatement.execute() - multiple queries in o...     12
# 1       Good branching and merging tutorials for Torto...      6
# 2                                       ASP.NET Site Maps      6
# 3                      Function for creating color wheels      6
# 4       Adding scripting functionality to .NET applica...      6
# ...                                                   ...    ...
# 953433      Why is a thread blocking my JavaFX UI Thread?      6
# 953434  GStreamer tutorial on Android getting 'Unsuppo...      6
# 953435              I am getting an undefined index error      6
# 953436  Bootstrapping to estimate the mean of a geomet...      6
# 953437                              Ruby: HTTP Put method      9
#
#                                       descripcion_cluster  \
# 0       Problemas de manejar multiples entidades: cone...
# 1       Temas generales de desarrollo: branching, scri...
# 2       Temas generales de desarrollo: branching, scri...
# 3       Temas generales de desarrollo: branching, scri...
# 4       Temas generales de desarrollo: branching, scri...
# ...                                                   ...
# 953433  Temas generales de desarrollo: branching, scri...
# 953434  Temas generales de desarrollo: branching, scri...
# 953435  Temas generales de desarrollo: branching, scri...
# 953436  Temas generales de desarrollo: branching, scri...
# 953437  Metodos y funciones: extension, reflexion, pas...
#
#                                                text_lower  \
# 0       sqlstatement.execute() - multiple queries in o...
# 1       good branching and merging tutorials for torto...
# 2                                       asp.net site maps
# 3                      function for creating color wheels
# 4       adding scripting functionality to .net applica...
# ...                                                   ...
# 953433      why is a thread blocking my javafx ui thread?
# 953434  gstreamer tutorial on android getting 'unsuppo...
# 953435              i am getting an undefined index error
# 953436  bootstrapping to estimate the mean of a geomet...
# 953437                              ruby: http put method
#
#                                               punc_remove  \
# 0       sqlstatement.execute  multiple queries in one ...
# 1       good branching and merging tutorials for torto...
# 2                                       asp.net site maps
# 3                      function for creating color wheels
# 4       adding scripting functionality to .net applica...
# ...                                                   ...
# 953433       why is a thread blocking my javafx ui thread
# 953434  gstreamer tutorial on android getting unsuppor...
# 953435              i am getting an undefined index error
# 953436  bootstrapping to estimate the mean of a geomet...
# 953437                               ruby http put method
#
#                                          stopwords_remove  \
# 0       sqlstatement.execute multiple queries one stat...
# 1            good branching merging tutorials tortoisesvn
# 2                                       asp.net site maps
# 3                          function creating color wheels
# 4        adding scripting functionality .net applications
# ...                                                   ...
# 953433                   thread blocking javafx ui thread
# 953434  gstreamer tutorial android getting unsupported...
# 953435                      getting undefined index error
# 953436       bootstrapping estimate mean geometric sample
# 953437                               ruby http put method
#
#                                          freq_word_remove  \
# 0       sqlstatement.execute multiple queries one stat...
# 1            good branching merging tutorials tortoisesvn
# 2                                       asp.net site maps
# 3                          function creating color wheels
# 4        adding scripting functionality .net applications
# ...                                                   ...
# 953433                   thread blocking javafx ui thread
# 953434  gstreamer tutorial getting unsupported profile...
# 953435                            getting undefined index
# 953436       bootstrapping estimate mean geometric sample
# 953437                               ruby http put method
#
#                                            text_lemmatize
# 0       sqlstatement.execute multiple query one statement
# 1             good branching merging tutorial tortoisesvn
# 2                                        asp.net site map
# 3                           function creating color wheel
# 4         adding scripting functionality .net application
# ...                                                   ...
# 953433                   thread blocking javafx ui thread
# 953434  gstreamer tutorial getting unsupported profile...
# 953435                            getting undefined index
# 953436       bootstrapping estimate mean geometric sample
# 953437                               ruby http put method
#
# [953438 rows x 12 columns]

# %%
df['text_without_number']= df['text_lemmatize'].apply(remove_numbers)
df['text_without_acc']= df['text_without_number'].apply(remove_account)
df.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z     26
# 1   90         58.0  2008-08-01T14:41:24Z    144
# 2  120         83.0  2008-08-01T15:50:08Z     21
# 3  180    2089740.0  2008-08-01T18:42:19Z     53
# 4  260         91.0  2008-08-01T23:22:08Z     49
#
#                                                 text  label  \
# 0  SQLStatement.execute() - multiple queries in o...     12
# 1  Good branching and merging tutorials for Torto...      6
# 2                                  ASP.NET Site Maps      6
# 3                 Function for creating color wheels      6
# 4  Adding scripting functionality to .NET applica...      6
#
#                                  descripcion_cluster  \
# 0  Problemas de manejar multiples entidades: cone...
# 1  Temas generales de desarrollo: branching, scri...
# 2  Temas generales de desarrollo: branching, scri...
# 3  Temas generales de desarrollo: branching, scri...
# 4  Temas generales de desarrollo: branching, scri...
#
#                                           text_lower  \
# 0  sqlstatement.execute() - multiple queries in o...
# 1  good branching and merging tutorials for torto...
# 2                                  asp.net site maps
# 3                 function for creating color wheels
# 4  adding scripting functionality to .net applica...
#
#                                          punc_remove  \
# 0  sqlstatement.execute  multiple queries in one ...
# 1  good branching and merging tutorials for torto...
# 2                                  asp.net site maps
# 3                 function for creating color wheels
# 4  adding scripting functionality to .net applica...
#
#                                     stopwords_remove  \
# 0  sqlstatement.execute multiple queries one stat...
# 1       good branching merging tutorials tortoisesvn
# 2                                  asp.net site maps
# 3                     function creating color wheels
# 4   adding scripting functionality .net applications
#
#                                     freq_word_remove  \
# 0  sqlstatement.execute multiple queries one stat...
# 1       good branching merging tutorials tortoisesvn
# 2                                  asp.net site maps
# 3                     function creating color wheels
# 4   adding scripting functionality .net applications
#
#                                       text_lemmatize  \
# 0  sqlstatement.execute multiple query one statement
# 1        good branching merging tutorial tortoisesvn
# 2                                   asp.net site map
# 3                      function creating color wheel
# 4    adding scripting functionality .net application
#
#                                  text_without_number  \
# 0  sqlstatement.execute multiple query one statement
# 1        good branching merging tutorial tortoisesvn
# 2                                   asp.net site map
# 3                      function creating color wheel
# 4    adding scripting functionality .net application
#
#                                     text_without_acc
# 0  sqlstatement.execute multiple query one statement
# 1        good branching merging tutorial tortoisesvn
# 2                                   asp.net site map
# 3                      function creating color wheel
# 4    adding scripting functionality .net application

# %%
permitidos = r'^[a-zA-ZáéíóúüñÁÉÍÓÚÜÑ\s¡!¿?,.;:()\'"-]+$'
mask = df['text_without_acc'].str.match(permitidos)
df_filtrado = df[mask].copy()

# %%
df_filtrado['text_clean'] = df_filtrado['text_without_acc'].str.replace(r'\s+', ' ', regex=True).str.strip()
df_filtrado = df_filtrado[df_filtrado['text_clean'].str.len() > 0]
df_filtrado = df_filtrado[df_filtrado['text_clean'].str.split().apply(len) >= 3]
df_filtrado.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z     26
# 1   90         58.0  2008-08-01T14:41:24Z    144
# 2  120         83.0  2008-08-01T15:50:08Z     21
# 3  180    2089740.0  2008-08-01T18:42:19Z     53
# 4  260         91.0  2008-08-01T23:22:08Z     49
#
#                                                 text  label  \
# 0  SQLStatement.execute() - multiple queries in o...     12
# 1  Good branching and merging tutorials for Torto...      6
# 2                                  ASP.NET Site Maps      6
# 3                 Function for creating color wheels      6
# 4  Adding scripting functionality to .NET applica...      6
#
#                                  descripcion_cluster  \
# 0  Problemas de manejar multiples entidades: cone...
# 1  Temas generales de desarrollo: branching, scri...
# 2  Temas generales de desarrollo: branching, scri...
# 3  Temas generales de desarrollo: branching, scri...
# 4  Temas generales de desarrollo: branching, scri...
#
#                                           text_lower  \
# 0  sqlstatement.execute() - multiple queries in o...
# 1  good branching and merging tutorials for torto...
# 2                                  asp.net site maps
# 3                 function for creating color wheels
# 4  adding scripting functionality to .net applica...
#
#                                          punc_remove  \
# 0  sqlstatement.execute  multiple queries in one ...
# 1  good branching and merging tutorials for torto...
# 2                                  asp.net site maps
# 3                 function for creating color wheels
# 4  adding scripting functionality to .net applica...
#
#                                     stopwords_remove  \
# 0  sqlstatement.execute multiple queries one stat...
# 1       good branching merging tutorials tortoisesvn
# 2                                  asp.net site maps
# 3                     function creating color wheels
# 4   adding scripting functionality .net applications
#
#                                     freq_word_remove  \
# 0  sqlstatement.execute multiple queries one stat...
# 1       good branching merging tutorials tortoisesvn
# 2                                  asp.net site maps
# 3                     function creating color wheels
# 4   adding scripting functionality .net applications
#
#                                       text_lemmatize  \
# 0  sqlstatement.execute multiple query one statement
# 1        good branching merging tutorial tortoisesvn
# 2                                   asp.net site map
# 3                      function creating color wheel
# 4    adding scripting functionality .net application
#
#                                  text_without_number  \
# 0  sqlstatement.execute multiple query one statement
# 1        good branching merging tutorial tortoisesvn
# 2                                   asp.net site map
# 3                      function creating color wheel
# 4    adding scripting functionality .net application
#
#                                     text_without_acc  \
# 0  sqlstatement.execute multiple query one statement
# 1        good branching merging tutorial tortoisesvn
# 2                                   asp.net site map
# 3                      function creating color wheel
# 4    adding scripting functionality .net application
#
#                                           text_clean
# 0  sqlstatement.execute multiple query one statement
# 1        good branching merging tutorial tortoisesvn
# 2                                   asp.net site map
# 3                      function creating color wheel
# 4    adding scripting functionality .net application

# %%
df_filtrado.head()
# Out:
# (951403, 15)

# %%
X = df_filtrado.drop('label', axis = 1) # Variables predictoras
Y = df_filtrado['label'] #Variable objetivo
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, stratify=Y)

# %%
X_train.head()
# Out:
#               Id  OwnerUserId          CreationDate  Score  \
# 677483  24295570    1119895.0  2014-06-18T21:49:25Z      2
# 115376   4997930     198128.0  2011-02-14T22:18:09Z      0
# 926402  32262340    2989124.0  2015-08-28T02:15:23Z      0
# 9675      652530      40872.0  2009-03-16T23:29:34Z     12
# 935353  32545260    5200233.0  2015-09-13T00:50:21Z      0
#
#                                                      text  \
# 677483  Protractor/Jasmine do not create folder for xu...
# 115376         Creating singleton - is this really right?
# 926402  How to organize test cases for a class with ma...
# 9675                       Neural networks - input values
# 935353           while loop not executing in Python 3.4.3
#
#                                       descripcion_cluster  \
# 677483  Temas generales de desarrollo: branching, scri...
# 115376  Temas generales de desarrollo: branching, scri...
# 926402  Metodos y funciones: extension, reflexion, pas...
# 9675    Problemas y valores por defecto en propiedades...
# 935353  Temas generales de desarrollo: branching, scri...
#
#                                                text_lower  \
# 677483  protractor/jasmine do not create folder for xu...
# 115376         creating singleton - is this really right?
# 926402  how to organize test cases for a class with ma...
# 9675                       neural networks - input values
# 935353           while loop not executing in python 3.4.3
#
#                                               punc_remove  \
# 677483  protractorjasmine do not create folder for xun...
# 115376           creating singleton  is this really right
# 926402  how to organize test cases for a class with ma...
# 9675                        neural networks  input values
# 935353           while loop not executing in python 3.4.3
#
#                                         stopwords_remove  \
# 677483  protractorjasmine create folder xunit file exist
# 115376                   creating singleton really right
# 926402            organize test cases class many methods
# 9675                        neural networks input values
# 935353                       loop executing python 3.4.3
#
#                                    freq_word_remove  \
# 677483  protractorjasmine create folder xunit exist
# 115376              creating singleton really right
# 926402       organize test cases class many methods
# 9675                   neural networks input values
# 935353                  loop executing python 3.4.3
#
#                                      text_lemmatize  \
# 677483  protractorjasmine create folder xunit exist
# 115376              creating singleton really right
# 926402         organize test case class many method
# 9675                     neural network input value
# 935353                  loop executing python 3.4.3
#
#                                 text_without_number  \
# 677483  protractorjasmine create folder xunit exist
# 115376              creating singleton really right
# 926402         organize test case class many method
# 9675                     neural network input value
# 935353                     loop executing python ..
#
#                                    text_without_acc  \
# 677483  protractorjasmine create folder xunit exist
# 115376              creating singleton really right
# 926402         organize test case class many method
# 9675                     neural network input value
# 935353                     loop executing python ..
#
#                                          text_clean
# 677483  protractorjasmine create folder xunit exist
# 115376              creating singleton really right
# 926402         organize test case class many method
# 9675                     neural network input value
# 935353                     loop executing python ..

# %%
Y_train
# Out:
# 677483    6
# 115376    6
# 926402    9
# 9675      1
# 935353    6
#          ..
# 87601     6
# 139131    6
# 625299    6
# 235194    6
# 360479    6
# Name: label, Length: 665982, dtype: int64

# %%
import joblib
vectorizer = joblib.load('vectorizer_tfidf.pkl')
len(vectorizer.vocabulary_)
# Out:
# 10432

# %%
X_train_vec = vectorizer.transform(X_train['text_clean'])
X_test_vec = vectorizer.transform(X_test['text_clean'])

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(max_iter=1000, random_state=23)
clf.fit(X_train_vec, Y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=23)

# %%
from sklearn.metrics import classification_report
y_pred = clf.predict(X_test_vec)
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       334
#            1       0.98      1.00      0.99     12177
#            2       0.99      0.99      0.99      5365
#            3       0.99      0.99      0.99     11047
#            4       0.99      0.99      0.99      5136
#            5       0.99      1.00      0.99     10657
#            6       1.00      1.00      1.00    202665
#            7       0.99      1.00      0.99      4558
#            8       0.99      0.99      0.99      7222
#            9       0.99      0.99      0.99      5017
#           10       0.99      1.00      0.99      3821
#           11       0.99      0.99      0.99      4110
#           12       1.00      0.98      0.99      5470
#           13       0.99      1.00      0.99      2625
#           14       0.99      1.00      0.99      5217
#
#     accuracy                           1.00    285421
#    macro avg       0.99      0.99      0.99    285421
# weighted avg       1.00      1.00      1.00    285421

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

modelos = {
    "LogReg": LogisticRegression(max_iter=1000),
    "NaiveBayes": MultinomialNB(alpha=0.1,class_prior=None,fit_prior=True),
    #"RandomForest": RandomForestClassifier(n_estimators=100), No se tuvo en cuenta pues su entrenamiento tarda demasiado tiempo
    "LinearSVM": LinearSVC()
}

resultados = {}

for nombre, modelo in modelos.items():
    modelo.fit(X_train_vec, Y_train)
    y_pred = modelo.predict(X_test_vec)
    resultados[nombre] = {
        "accuracy": accuracy_score(Y_test, y_pred),
        "macro_f1": classification_report(Y_test, y_pred, output_dict=True)['macro avg']['f1-score']
    }
pd.DataFrame(resultados).T.sort_values("macro_f1", ascending=False)
# Out:
#             accuracy  macro_f1
# LogReg      0.997211  0.992303
# LinearSVM   0.996097  0.990993
# NaiveBayes  0.902355  0.777037

# %%
from sklearn.model_selection import GridSearchCV
nb_model = MultinomialNB()
param_grid = {
    'alpha': [0.1, 0.5, 1.0, 2.0, 5.0],
    'fit_prior': [True, False],
    'class_prior': [None, [0.5, 0.5]]
}
grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, 
                           scoring='f1_macro',
                           cv=5,
                           n_jobs=-1)

grid_search.fit(X_train_vec, Y_train)

print(f"Mejores hiperparametros encontrados: {grid_search.best_params_}")
print(f"Mejor puntuacion F1: {grid_search.best_score_}")
# Out:
# Mejores hiperparámetros encontrados: {'alpha': 0.1, 'class_prior': None, 'fit_prior': True}
# Mejor puntuación F1: 0.7726895351280352

# %%
mejor_nombre_modelo = pd.DataFrame(resultados).T.sort_values("macro_f1", ascending=False).index[0]
mejor_modelo_final = modelos[mejor_nombre_modelo]
mejor_modelo_final.fit(X_train_vec, Y_train)
joblib.dump(mejor_modelo_final, 'mejor_modelo.pkl')
# Out:
# ['mejor_modelo.pkl']

# %% [markdown]
# ## Validacion

# %%
df_val = pd.read_csv(f'{path}/Questions.csv', encoding='latin1')[1000001:]
df_val['text'] = df_val['Title'].astype(str)
df_val = df_val.reset_index(drop=True)
df_val['text_lower'] = df_val['text'].str.lower()
punc_to_remove= string.punctuation.replace('.','')
df_val['punc_remove']=df_val['text_lower'].apply(remove_punc)
stpwords= set(stopwords.words('english'))
df_val['stopwords_remove']= df_val['punc_remove'].apply(lambda text: remove_stopwords(text,stpwords))
for t in df_val['stopwords_remove'].values:
   for w in t.split():
        ct[w] +=1

freqwords = set([w for (w, wc) in ct.most_common(10)])
df_val['freq_word_remove']= df_val['stopwords_remove'].apply(remove_freqwords)
lemmatizer= WordNetLemmatizer()
df_val['text_lemmatize']= df_val['freq_word_remove'].apply(lemmatize_words)
df_val['text_without_number']= df_val['text_lemmatize'].apply(remove_numbers)
df_val['text_without_acc']= df_val['text_without_number'].apply(remove_account)
permitidos = r'^[a-zA-ZáéíóúüñÁÉÍÓÚÜÑ\s¡!¿?,.;:()\'"-]+$'
mask = df_val['text_without_acc'].str.match(permitidos)
df_val = df_val[mask].copy()
df_val['text_clean'] = df_val['text_without_acc'].str.replace(r'\s+', ' ', regex=True).str.strip()
df_val = df_val[df_val['text_clean'].str.len() > 0]
df_val = df_val[df_val['text_clean'].str.split().apply(len) >= 3]
df_val.head()
# Out:
#          Id  OwnerUserId          CreationDate ClosedDate  Score  \
# 0  33112810    5442551.0  2015-10-13T21:18:49Z        NaN      0
# 1  33112960    5344839.0  2015-10-13T21:29:01Z        NaN      0
# 2  33113000     682059.0  2015-10-13T21:31:13Z        NaN      0
# 3  33113010    2720343.0  2015-10-13T21:32:09Z        NaN      4
# 5  33113070    5282582.0  2015-10-13T21:36:18Z        NaN     -1
#
#                                                Title  \
# 0  how can I set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  Tomcat webapp NoClassDefFoundError with jar on...
# 3            Color error with OpenGL Texture Formats
# 5             insert into select statment inner join
#
#                                                 Body  \
# 0  <p>I am trying to set up a backup tool for use...
# 1  <p>I have a select statement that looks like t...
# 2  <p>Experiencing a NoClassDefFoundError when de...
# 3  <p>I'm trying to load an image using FreeImage...
# 5  <p>I have two valuues which I want to insert i...
#
#                                                 text  \
# 0  how can I set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  Tomcat webapp NoClassDefFoundError with jar on...
# 3            Color error with OpenGL Texture Formats
# 5             insert into select statment inner join
#
#                                           text_lower  \
# 0  how can i set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  tomcat webapp noclassdeffounderror with jar on...
# 3            color error with opengl texture formats
# 5             insert into select statment inner join
#
#                                          punc_remove  \
# 0  how can i set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  tomcat webapp noclassdeffounderror with jar on...
# 3            color error with opengl texture formats
# 5             insert into select statment inner join
#
#                                    stopwords_remove  \
# 0         set permissions batch file mkdir creation
# 1                    using subquery get results sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                color error opengl texture formats
# 5                 insert select statment inner join
#
#                                    freq_word_remove  \
# 0              set permissions batch mkdir creation
# 1                              subquery results sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                      color opengl texture formats
# 5                 insert select statment inner join
#
#                                      text_lemmatize  \
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join
#
#                                 text_without_number  \
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join
#
#                                    text_without_acc  \
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join
#
#                                          text_clean
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join

# %%
vectorizer = joblib.load('vectorizer_tfidf.pkl')
modelo = joblib.load('mejor_modelo.pkl')
df_val.head()
# Out:
#          Id  OwnerUserId          CreationDate ClosedDate  Score  \
# 0  33112810    5442551.0  2015-10-13T21:18:49Z        NaN      0
# 1  33112960    5344839.0  2015-10-13T21:29:01Z        NaN      0
# 2  33113000     682059.0  2015-10-13T21:31:13Z        NaN      0
# 3  33113010    2720343.0  2015-10-13T21:32:09Z        NaN      4
# 5  33113070    5282582.0  2015-10-13T21:36:18Z        NaN     -1
#
#                                                Title  \
# 0  how can I set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  Tomcat webapp NoClassDefFoundError with jar on...
# 3            Color error with OpenGL Texture Formats
# 5             insert into select statment inner join
#
#                                                 Body  \
# 0  <p>I am trying to set up a backup tool for use...
# 1  <p>I have a select statement that looks like t...
# 2  <p>Experiencing a NoClassDefFoundError when de...
# 3  <p>I'm trying to load an image using FreeImage...
# 5  <p>I have two valuues which I want to insert i...
#
#                                                 text  \
# 0  how can I set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  Tomcat webapp NoClassDefFoundError with jar on...
# 3            Color error with OpenGL Texture Formats
# 5             insert into select statment inner join
#
#                                           text_lower  \
# 0  how can i set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  tomcat webapp noclassdeffounderror with jar on...
# 3            color error with opengl texture formats
# 5             insert into select statment inner join
#
#                                          punc_remove  \
# 0  how can i set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  tomcat webapp noclassdeffounderror with jar on...
# 3            color error with opengl texture formats
# 5             insert into select statment inner join
#
#                                    stopwords_remove  \
# 0         set permissions batch file mkdir creation
# 1                    using subquery get results sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                color error opengl texture formats
# 5                 insert select statment inner join
#
#                                    freq_word_remove  \
# 0              set permissions batch mkdir creation
# 1                              subquery results sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                      color opengl texture formats
# 5                 insert select statment inner join
#
#                                      text_lemmatize  \
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join
#
#                                 text_without_number  \
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join
#
#                                    text_without_acc  \
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join
#
#                                          text_clean
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join

# %%
df_val_vec = vectorizer.transform(df_val['text_clean'])
df_val_pred = modelo.predict(df_val_vec)

# %%
df_val['predicciones'] = df_val_pred
df_val.head()
# Out:
#          Id  OwnerUserId          CreationDate ClosedDate  Score  \
# 0  33112810    5442551.0  2015-10-13T21:18:49Z        NaN      0
# 1  33112960    5344839.0  2015-10-13T21:29:01Z        NaN      0
# 2  33113000     682059.0  2015-10-13T21:31:13Z        NaN      0
# 3  33113010    2720343.0  2015-10-13T21:32:09Z        NaN      4
# 5  33113070    5282582.0  2015-10-13T21:36:18Z        NaN     -1
#
#                                                Title  \
# 0  how can I set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  Tomcat webapp NoClassDefFoundError with jar on...
# 3            Color error with OpenGL Texture Formats
# 5             insert into select statment inner join
#
#                                                 Body  \
# 0  <p>I am trying to set up a backup tool for use...
# 1  <p>I have a select statement that looks like t...
# 2  <p>Experiencing a NoClassDefFoundError when de...
# 3  <p>I'm trying to load an image using FreeImage...
# 5  <p>I have two valuues which I want to insert i...
#
#                                                 text  \
# 0  how can I set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  Tomcat webapp NoClassDefFoundError with jar on...
# 3            Color error with OpenGL Texture Formats
# 5             insert into select statment inner join
#
#                                           text_lower  \
# 0  how can i set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  tomcat webapp noclassdeffounderror with jar on...
# 3            color error with opengl texture formats
# 5             insert into select statment inner join
#
#                                          punc_remove  \
# 0  how can i set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  tomcat webapp noclassdeffounderror with jar on...
# 3            color error with opengl texture formats
# 5             insert into select statment inner join
#
#                                    stopwords_remove  \
# 0         set permissions batch file mkdir creation
# 1                    using subquery get results sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                color error opengl texture formats
# 5                 insert select statment inner join
#
#                                    freq_word_remove  \
# 0              set permissions batch mkdir creation
# 1                              subquery results sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                      color opengl texture formats
# 5                 insert select statment inner join
#
#                                      text_lemmatize  \
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join
#
#                                 text_without_number  \
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join
#
#                                    text_without_acc  \
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join
#
#                                          text_clean  predicciones
# 0               set permission batch mkdir creation             6
# 1                               subquery result sql             6
# 2  tomcat webapp noclassdeffounderror jar classpath             6
# 3                       color opengl texture format             6
# 5                 insert select statment inner join             6

# %%
cluster_resumen = {
    0: "Uso de anotaciones en Java, Spring, Hibernate, Struts y serializacion; tambien incluye anotaciones en plataformas moviles como MKMapView.",
    1: "Problemas y valores por defecto en propiedades, debugging en Visual Studio, issues con jQuery, AJAX y almacenamiento de valores.",
    2: "Interaccion con paginas web: flujo de paginas, autorizacion, cache, multiples formularios y manejo de POST en distintas tecnologias.",
    3: "Consultas SQL, HTML, manejo de tablas y normalizacion; incluye manipulacion de DOM y diferencias entre tablas y CSS.",
    4: "Listas en programacion: manipulacion, agrupacion, delegados, estructuras en SharePoint y frameworks como Scala y Python.",
    5: "Operaciones con strings, performance en concatenacion, parsing, analisis de codigo, errores de base de datos, e integracion de frameworks.",
    6: "Temas generales de desarrollo: branching, scripting, unit testing, consumo de servicios, configuracion de proyectos y triggers.",
    7: "Bases de datos: conexion, estructura, testing, engines, ACL en CakePHP, denormalizacion y patrones de diseno de acceso.",
    8: "Consultas SQL en MySQL y errores comunes: replicacion, triggers, stored procedures, logs binarios y sugerencias de autocompletado.",
    9: "Metodos y funciones: extension, reflexion, paso de parametros, testing, seguridad, diseno orientado a objetos y metaprogramacion.",
    10: "Como 'hacer que algo funcione': URLs amigables, CSS, visual studio, controles personalizados, git, SOAP, Flex y accesibilidad.",
    11: "Preguntas sobre 'como funciona' algo: statements preparados, QA, CSS, validacion W3C, threading, SOA, omnicomplete y Scrum.",
    12: "Problemas de manejar multiples entidades: conexiones, versiones, tablas, lenguajes, servidores, layouts, colecciones y parches.",
    13: "Paso de parametros en multiples lenguajes y entornos: SQL, C, C++, Java, Ruby, Oracle, jQuery, funciones y referencias.",
    14: "Errores de 'no funciona': debugging, __doPostBack, CSS, eventos en jQuery, atributos, visualizacion, Mercurial y fechas."
}
df_val['descripcion_cluster'] = df_val['predicciones'].map(cluster_resumen)
df_val.head()
# Out:
#          Id  OwnerUserId          CreationDate ClosedDate  Score  \
# 0  33112810    5442551.0  2015-10-13T21:18:49Z        NaN      0
# 1  33112960    5344839.0  2015-10-13T21:29:01Z        NaN      0
# 2  33113000     682059.0  2015-10-13T21:31:13Z        NaN      0
# 3  33113010    2720343.0  2015-10-13T21:32:09Z        NaN      4
# 5  33113070    5282582.0  2015-10-13T21:36:18Z        NaN     -1
#
#                                                Title  \
# 0  how can I set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  Tomcat webapp NoClassDefFoundError with jar on...
# 3            Color error with OpenGL Texture Formats
# 5             insert into select statment inner join
#
#                                                 Body  \
# 0  <p>I am trying to set up a backup tool for use...
# 1  <p>I have a select statement that looks like t...
# 2  <p>Experiencing a NoClassDefFoundError when de...
# 3  <p>I'm trying to load an image using FreeImage...
# 5  <p>I have two valuues which I want to insert i...
#
#                                                 text  \
# 0  how can I set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  Tomcat webapp NoClassDefFoundError with jar on...
# 3            Color error with OpenGL Texture Formats
# 5             insert into select statment inner join
#
#                                           text_lower  \
# 0  how can i set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  tomcat webapp noclassdeffounderror with jar on...
# 3            color error with opengl texture formats
# 5             insert into select statment inner join
#
#                                          punc_remove  \
# 0  how can i set permissions to a batch file mkdi...
# 1                using a subquery to get results sql
# 2  tomcat webapp noclassdeffounderror with jar on...
# 3            color error with opengl texture formats
# 5             insert into select statment inner join
#
#                                    stopwords_remove  \
# 0         set permissions batch file mkdir creation
# 1                    using subquery get results sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                color error opengl texture formats
# 5                 insert select statment inner join
#
#                                    freq_word_remove  \
# 0              set permissions batch mkdir creation
# 1                              subquery results sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                      color opengl texture formats
# 5                 insert select statment inner join
#
#                                      text_lemmatize  \
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join
#
#                                 text_without_number  \
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join
#
#                                    text_without_acc  \
# 0               set permission batch mkdir creation
# 1                               subquery result sql
# 2  tomcat webapp noclassdeffounderror jar classpath
# 3                       color opengl texture format
# 5                 insert select statment inner join
#
#                                          text_clean  predicciones  \
# 0               set permission batch mkdir creation             6
# 1                               subquery result sql             6
# 2  tomcat webapp noclassdeffounderror jar classpath             6
# 3                       color opengl texture format             6
# 5                 insert select statment inner join             6
#
#                                  descripcion_cluster
# 0  Temas generales de desarrollo: branching, scri...
# 1  Temas generales de desarrollo: branching, scri...
# 2  Temas generales de desarrollo: branching, scri...
# 3  Temas generales de desarrollo: branching, scri...
# 5  Temas generales de desarrollo: branching, scri...
